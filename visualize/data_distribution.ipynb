# %%
import torch
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import sys
import os
import numpy as np
from itertools import chain
import json

# %%
info_path = '../fedtask/synthetic_classification_cnum10_dist10_skew0.5_seed0/data.json'
f = open(info_path)
data = json.load(f)

# %%
count_labels = np.zeros((10,))

for i in range(10):
    count_labels[i] = (data['dtest']['y']).count(i)

# %%
plt.bar(np.arange(10), count_labels)
plt.title('Data distribution of test dataset')
plt.show()

# %%
for name in data['client_names']:
    print(data[name]['optimal'])
# Out:
# [[1.8374758732029182, 2.2756749952364044, 0.34932579269210245, 1.036690676911182, 1.3536615260107845, 1.0196757215441132, 1.766395503545641, 0.4769896686143109, 0.5716212088836874, -0.12279777162539207], [2.0212626551461406, -1.3096097776114535, 1.6372673016471309, -0.9573119383983593, 0.8980411710722904, 1.6737277631252683, 2.007372018572406, 0.6904765509246743, 1.5324462002548604, -1.408693701756011], [2.2581865398949397, 0.8583779564302283, 0.9496183970704335, 0.8210611336927726, -1.019560375198356, 1.2252601587600904, -1.0955866318833503, -0.465008672155681, 1.1317350235116985, 0.39259387678182894], [-0.517753998206429, -0.27184742339727275, 0.7461876087043059, -0.2442373017018804, 0.20342582998369585, 1.1068034396407347, 2.743339956310813, 1.3216710617508607, 0.7996483509526152, 0.7023213513224695], [1.294432820852453, 0.8558427991897168, 1.9190051358762548, -0.9442470490358246, 0.7744762774225906, -0.9434861058627495, 0.9371345076735453, 0.5808627388725599, 2.410255347651679, -
# ...
